# %% [markdown]
# <a href="https://colab.research.google.com/github/AanchalDogra/Topic_Modelling/blob/main/NER_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import keras

# %%
# hyperparameters if GPU is available
if tf.test.is_gpu_available():

# %%
if tf.test.is_gpu_available():
  BATCH_SIZE = 500 # number of examples used in each iteration
  EPOCHS = 5 # number of passes of entire dataset
  MAX_LEN = 75 # max_len of review in words
  EMBEDDING = 40 #Dimension of word embedding Vector
else:
  BATCH_SIZE = 32 # number of examples used in each iteration
  EPOCHS = 5 # number of passes of entire dataset
  MAX_LEN = 75 # max_len of review in words
  EMBEDDING = 20 #Dimension of word embedding Vector

# %% [markdown]
#   BATCH_SIZE = 500 # number of examples used in each iteration
#   EPOCHS = 5 # number of passes of entire dataset
#   MAX_LEN = 75 # max_len of review in words
#   EMBEDDING = 40 #Dimension of word embedding Vector

# %%
# !gdown 1ao5aINQqedAWHSXGLpAVzW1iEZj7sZ5_
# !gdown 15RuVEDqO592th-44iVEpcGbtvX9RjDWR
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ao5aINQqedAWHSXGLpAVzW1iEZj7sZ5_
# To: /content/ner_dataset.csv
# 100% 15.2M/15.2M [00:00<00:00, 131MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=15RuVEDqO592th-44iVEpcGbtvX9RjDWR
# To: /content/drugsComTrain_raw.csv
# 100% 1.38M/1.38M [00:00<00:00, 17.6MB/s]

# %%
df = pd.read_csv('ner_dataset.csv', encoding = 'latin1')

# %%
df.sample(9)
# Out:
#              Sentence #       Word  POS Tag
# 217305              NaN  extensive   JJ   O
# 202955              NaN     killed  VBN   O
# 1011240             NaN      those   DT   O
# 982843              NaN      since   IN   O
# 71793               NaN         to   TO   O
# 211145   Sentence: 9678     Police  NNS   O
# 492887              NaN   Governor  NNP   O
# 117388              NaN      offer   NN   O
# 685016              NaN       army   NN   O

# %%
df = df.fillna(method = 'ffill')
df.head()
# Out:
#     Sentence #           Word  POS Tag
# 0  Sentence: 1      Thousands  NNS   O
# 1  Sentence: 1             of   IN   O
# 2  Sentence: 1  demonstrators  NNS   O
# 3  Sentence: 1           have  VBP   O
# 4  Sentence: 1        marched  VBN   O

# %%
df.head(25)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O
# 20  Sentence: 1           from   IN      O
# ...
